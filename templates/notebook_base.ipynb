# %% [markdown]
# ## **Semana {{WEEK_CODE}} – {{THEME}}** ✨

# %% [markdown]
# **Dataset:** {{DATASET_URL}}
# **Fuente:** {{SOURCE_URL}}
# **Fecha de publicación:** {{PUBLISHED_DATE}}

# %% [markdown]
# ### **1. Contexto y preguntas iniciales** 📋
# - ¿Qué historia cuenta el dataset?
# - ¿Cuál es la visualización original a rehacer?
# - Hipótesis o preguntas que queremos explorar.

# %%
# 2. Imports y configuraciones iniciales
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

RAW_PATH = 'data/raw/{{RAW_FILENAME}}'
PROCESSED_PATH = 'data/processed/{{PROCESSED_FILENAME}}'

# %% [markdown]
# ### **3. Exploración inicial** 🔍

# %%
raw_df = pd.read_csv(RAW_PATH)
raw_df.head()

# %% [markdown]
# ### **4. Limpieza y transformación** 🧼

# %%
processed_df = raw_df.copy()
# TODO: agregar pasos de limpieza
processed_df.to_csv(PROCESSED_PATH, index=False)

# %% [markdown]
# ### **5. Visualizaciones** 📊

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.barplot(data=processed_df, x='{{DIMENSION}}', y='{{METRIC}}', ax=ax)
ax.set_title('{{CHART_TITLE}}')

# %% [markdown]
# ### **6. Conclusiones y próximos pasos** 🚀
# - Insight principal 1
# - Insight principal 2
# - Ideas para iteraciones futuras.
